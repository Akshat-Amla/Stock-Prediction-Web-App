# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as data

# %%
# !pip install --upgrade pandas-datareader
# !pip install yfinance
# Out:
# Requirement already satisfied: pandas-datareader in c:\users\jeeva\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: lxml in c:\users\jeeva\anaconda3\lib\site-packages (from pandas-datareader) (4.9.3)
# Requirement already satisfied: pandas>=0.23 in c:\users\jeeva\anaconda3\lib\site-packages (from pandas-datareader) (2.1.4)
# Requirement already satisfied: requests>=2.19.0 in c:\users\jeeva\anaconda3\lib\site-packages (from pandas-datareader) (2.31.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\jeeva\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jeeva\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jeeva\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\jeeva\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jeeva\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jeeva\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jeeva\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jeeva\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2024.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\jeeva\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader) (1.16.0)
# Requirement already satisfied: yfinance in c:\users\jeeva\anaconda3\lib\site-packages (0.2.37)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\jeeva\anaconda3\lib\site-packages (from yfinance) (2.1.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\jeeva\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\jeeva\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\jeeva\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\jeeva\anaconda3\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\jeeva\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\jeeva\anaconda3\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\jeeva\anaconda3\lib\site-packages (from yfinance) (2.4.0)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\jeeva\anaconda3\lib\site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\jeeva\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\jeeva\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jeeva\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\users\jeeva\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\jeeva\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jeeva\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\jeeva\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jeeva\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jeeva\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jeeva\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jeeva\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2024.2.2)

# %%
import yfinance as yf
start='2010-01-01'
end='2024-03-12'
df = yf.download('AAPL', start, end)

# Display the first few rows of the data
print(df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-01-04  7.622500  7.660714  7.585000  7.643214   6.470741  493729600
# 2010-01-05  7.664286  7.699643  7.616071  7.656429   6.481930  601904800
# 2010-01-06  7.656429  7.686786  7.526786  7.534643   6.378826  552160000
# 2010-01-07  7.562500  7.571429  7.466071  7.520714   6.367033  477131200
# 2010-01-08  7.510714  7.571429  7.466429  7.570714   6.409362  447610800

# %%
# Display the last few rows of the data
print(df.tail())
df = df.reset_index()
df.head()
df = df.drop(['Date', 'Adj Close'], axis = 1)
df.head()
plt.plot(df.Close)
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-03-05  170.759995  172.039993  169.619995  170.119995  170.119995
# 2024-03-06  171.059998  171.240005  168.679993  169.119995  169.119995
# 2024-03-07  169.149994  170.729996  168.490005  169.000000  169.000000
# 2024-03-08  169.000000  173.699997  168.940002  170.729996  170.729996
# 2024-03-11  172.940002  174.380005  172.050003  172.750000  172.750000
#
#               Volume
# Date
# 2024-03-05  95132400
# 2024-03-06  68587700
# 2024-03-07  71765100
# 2024-03-08  76114600
# 2024-03-11  60139500
#             Open        High         Low       Close     Volume
# 0       7.622500    7.660714    7.585000    7.643214  493729600
# 1       7.664286    7.699643    7.616071    7.656429  601904800
# 2       7.656429    7.686786    7.526786    7.534643  552160000
# 3       7.562500    7.571429    7.466071    7.520714  477131200
# 4       7.510714    7.571429    7.466429    7.570714  447610800
# ...          ...         ...         ...         ...        ...
# 3565  170.759995  172.039993  169.619995  170.119995   95132400
# 3566  171.059998  171.240005  168.679993  169.119995   68587700
# 3567  169.149994  170.729996  168.490005  169.000000   71765100
# 3568  169.000000  173.699997  168.940002  170.729996   76114600
# 3569  172.940002  174.380005  172.050003  172.750000   60139500
#
# [3570 rows x 5 columns]

# %%
ma100 = df.Close.rolling(100).mean()
ma100
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100,'r')

# %%
ma200 = df.Close.rolling(200).mean()
ma200
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100,'r')
plt.plot(ma200,'g')
df.shape
# Out:
# (3570, 5)

# %%
data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70): int (len(df))])

print(data_training.shape)
print(data_testing.shape)
# Out:
# (2499, 1)
# (1071, 1)

# %%
data_training.head()
data_testing.head()
# Out:
#           Close
# 2499  67.677498
# 2500  66.730003
# 2501  67.120003
# 2502  67.692497
# 2503  67.864998

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
data_training_array = scaler.fit_transform(data_training)
data_training_array
# Out:
# array([[0.01304944],
#        [0.01326931],
#        [0.01124296],
#        ...,
#        [0.96510052],
#        [0.97462605],
#        [0.99059913]])

# %%
x_train = []
y_train = []
for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i - 100: i])
    y_train.append(data_training_array[i, 0])
    
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# !pip install keras
# !pip install tensorflow
# Out:
# Requirement already satisfied: keras in c:\users\jeeva\anaconda3\lib\site-packages (3.0.5)
# Requirement already satisfied: absl-py in c:\users\jeeva\anaconda3\lib\site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\jeeva\anaconda3\lib\site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in c:\users\jeeva\anaconda3\lib\site-packages (from keras) (13.3.5)
# Requirement already satisfied: namex in c:\users\jeeva\anaconda3\lib\site-packages (from keras) (0.0.7)
# Requirement already satisfied: h5py in c:\users\jeeva\anaconda3\lib\site-packages (from keras) (3.10.0)
# Requirement already satisfied: dm-tree in c:\users\jeeva\anaconda3\lib\site-packages (from keras) (0.1.8)
# Requirement already satisfied: ml-dtypes in c:\users\jeeva\anaconda3\lib\site-packages (from keras) (0.3.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\jeeva\anaconda3\lib\site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jeeva\anaconda3\lib\site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jeeva\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras) (0.1.0)
# Requirement already satisfied: tensorflow in c:\users\jeeva\anaconda3\lib\site-packages (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.7)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.0.5)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\jeeva\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.41.2)
# Requirement already satisfied: rich in c:\users\jeeva\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.3.5)
# Requirement already satisfied: namex in c:\users\jeeva\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.7)
# Requirement already satisfied: dm-tree in c:\users\jeeva\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jeeva\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jeeva\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jeeva\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jeeva\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\jeeva\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\jeeva\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\jeeva\anaconda3\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jeeva\anaconda3\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jeeva\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.0)

# %%
#ML model
from keras.layers import Dense, Dropout , LSTM
from keras.models import Sequential

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\jeeva\anaconda3\lib\site-packages (3.0.5)
# Requirement already satisfied: absl-py in c:\users\jeeva\anaconda3\lib\site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\jeeva\anaconda3\lib\site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in c:\users\jeeva\anaconda3\lib\site-packages (from keras) (13.3.5)
# Requirement already satisfied: namex in c:\users\jeeva\anaconda3\lib\site-packages (from keras) (0.0.7)
# Requirement already satisfied: h5py in c:\users\jeeva\anaconda3\lib\site-packages (from keras) (3.10.0)
# Requirement already satisfied: dm-tree in c:\users\jeeva\anaconda3\lib\site-packages (from keras) (0.1.8)
# Requirement already satisfied: ml-dtypes in c:\users\jeeva\anaconda3\lib\site-packages (from keras) (0.3.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\jeeva\anaconda3\lib\site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jeeva\anaconda3\lib\site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jeeva\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras) (0.1.0)

# %%
model = Sequential()
model.add(LSTM(units = 50 ,activation= 'relu' , return_sequences= True , input_shape= (x_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units = 60 ,activation= 'relu' , return_sequences= True ))
model.add(Dropout(0.3))

model.add(LSTM(units = 80 ,activation= 'relu' , return_sequences= True ))
model.add(Dropout(0.4))

model.add(LSTM(units = 120 ,activation= 'relu' ))
model.add(Dropout(0.5))

model.add(Dense(units=1))
# Out:
# C:\Users\jeeva\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 100, 50)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100, 60)        │        26,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 100, 60)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 100, 80)        │        45,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 100, 80)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 120)            │        96,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 120)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           121 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 178,761 (698.29 KB)
#  Trainable params: 178,761 (698.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer= 'adam',loss='mean_squared_error')
model.fit(x_train,y_train,epochs=50)
# Out:
# Epoch 1/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - loss: 0.0564
# Epoch 2/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 0.0058
# Epoch 3/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 0.0047
# Epoch 4/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 0.0049
# Epoch 5/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 0.0057
# Epoch 6/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 0.0042
# Epoch 7/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 0.0039
# Epoch 8/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 0.0037
# Epoch 9/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 0.0039
# Epoch 10/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 0.0034
# Epoch 11/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 0.0032
# Epoch 12/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 0.0032
# Epoch 13/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 0.0031
# Epoch 14/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 0.0029
# Epoch 15/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 0.0027
# Epoch 16/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 0.0022
# Epoch 17/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - loss: 0.0026
# Epoch 18/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step - loss: 0.0023
# Epoch 19/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - loss: 0.0026
# Epoch 20/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - loss: 0.0028
# Epoch 21/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 0.0023
# Epoch 22/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 0.0023
# Epoch 23/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - loss: 0.0026
# Epoch 24/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - loss: 0.0023
# Epoch 25/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - loss: 0.0020
# Epoch 26/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 0.0023
# Epoch 27/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 0.0020
# Epoch 28/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - loss: 0.0019
# Epoch 29/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - loss: 0.0021
# Epoch 30/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - loss: 0.0022
# Epoch 31/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - loss: 0.0019
# Epoch 32/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 0.0021
# Epoch 33/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 0.0019
# Epoch 34/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 0.0020
# Epoch 35/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 0.0018
# Epoch 36/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 0.0020
# Epoch 37/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 0.0017
# Epoch 38/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 0.0019
# Epoch 39/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 0.0020
# Epoch 40/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - loss: 0.0017
# Epoch 41/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 0.0019
# Epoch 42/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 0.0015
# Epoch 43/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 0.0020
# Epoch 44/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - loss: 0.0016
# Epoch 45/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 0.0018
# Epoch 46/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 0.0016
# Epoch 47/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 0.0016
# Epoch 48/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 0.0018
# Epoch 49/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 0.0018
# Epoch 50/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 0.0017

# %%
model.save('Keras_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
data_testing.head()
# Out:
#           Close
# 2499  67.677498
# 2500  66.730003
# 2501  67.120003
# 2502  67.692497
# 2503  67.864998

# %%
data_training.tail()
# Out:
#           Close
# 2494  66.812500
# 2495  66.040001
# 2496  64.862503
# 2497  65.434998
# 2498  66.394997

# %%
past_100_days = data_training.tail(100)

# %%
final_df = pd.concat([past_100_days, data_testing], ignore_index=True)

# %%
final_df.head()
# Out:
#        Close
# 0  50.837502
# 1  51.415001
# 2  50.647499
# 3  51.805000
# 4  52.209999

# %%
input_data = scaler.fit_transform(final_df)
input_data
# Out:
# array([[0.01670841],
#        [0.02056419],
#        [0.01543983],
#        ...,
#        [0.80564179],
#        [0.81719242],
#        [0.83067935]])

# %%
input_data.shape
# Out:
# (1171, 1)

# %%
x_test = []
y_test = []

for i in range(100, input_data.shape[0]):
    x_test.append(input_data[i - 100: i])
    y_test.append(input_data[i, 0])

# %%
x_test, y_test = np.array(x_test), np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1071, 100, 1)
# (1071,)

# %%
#Making Predictions
y_predicted = model.predict(x_test)
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step

# %%
y_predicted.shape
# Out:
# (1071, 1)

# %%
y_test
# Out:
# array([0.12914371, 0.12281759, 0.12542149, ..., 0.80564179, 0.81719242,
#        0.83067935])

# %%
y_predicted
# Out:
# array([[0.17263393],
#        [0.17308821],
#        [0.173479  ],
#        ...,
#        [0.79606736],
#        [0.78837514],
#        [0.77944726]], dtype=float32)

# %%
scaler.scale_
# Out:
# array([0.00667668])

# %%
scale_factor = 1/0.00667668
y_predicted = y_predicted * scale_factor
y_test = y_test * scale_factor

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test, 'b', label = 'Original Price')
plt.plot(y_predicted, 'r', label = 'Predicted Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
